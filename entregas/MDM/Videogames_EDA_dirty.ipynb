# %% [markdown]
# # Ensuciando dataset

# %%
import pandas as pd
import numpy as np

# %%
videogames = pd.read_csv("./datasets/vgsales.csv", index_col=0)

# %%
videogames
# Out:
#                                                    Name Platform    Year  \
# Rank
# 1                                            Wii Sports      Wii  2006.0
# 2                                     Super Mario Bros.      NES  1985.0
# 3                                        Mario Kart Wii      Wii  2008.0
# 4                                     Wii Sports Resort      Wii  2009.0
# 5                              Pokemon Red/Pokemon Blue       GB  1996.0
# ...                                                 ...      ...     ...
# 16596                Woody Woodpecker in Crazy Castle 5      GBA  2002.0
# 16597                     Men in Black II: Alien Escape       GC  2003.0
# 16598  SCORE International Baja 1000: The Official Game      PS2  2008.0
# 16599                                        Know How 2       DS  2010.0
# 16600                                  Spirits & Spells      GBA  2003.0
#
#               Genre   Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# Rank
# ...

# %%
videogames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16598 entries, 1 to 16600
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          16598 non-null  object
#  1   Platform      16598 non-null  object
#  2   Year          16327 non-null  float64
#  3   Genre         16598 non-null  object
#  4   Publisher     16540 non-null  object
#  5   NA_Sales      16598 non-null  float64
#  6   EU_Sales      16598 non-null  float64
#  7   JP_Sales      16598 non-null  float64
#  8   Other_Sales   16598 non-null  float64
#  9   Global_Sales  16598 non-null  float64
# dtypes: float64(6), object(4)
# memory usage: 1.4+ MB

# %%
nulls = videogames.isnull().sum()
rows = videogames.shape[0]

percentage = nulls / rows
table = pd.concat([nulls, percentage], axis=1, keys=['Nulos', 'Porcentaje %'])
ordered_table = table.sort_values(by='Porcentaje %', ascending=False)

print(ordered_table)
# Out:
#               Nulos  Porcentaje %
# Year            271      0.016327
# Publisher        58      0.003494
# Name              0      0.000000
# Platform          0      0.000000
# Genre             0      0.000000
# NA_Sales          0      0.000000
# EU_Sales          0      0.000000
# JP_Sales          0      0.000000
# Other_Sales       0      0.000000
# Global_Sales      0      0.000000

# %% [markdown]
# ## Introduciendo valores nulos

# %% [markdown]
# Introducimos un numero aleatorio de valores nulos en columnas aleatorias

# %%
num_columnas = videogames.shape[1]

# Elegir aleatoriamente 4 columnas
columnas_con_nulos = np.random.choice(videogames.columns, size=6)

# Seleccionar aleatoriamente el numero de nulos
num_nulos_por_columna = np.random.randint(1, 150, size=4)

# Introducir nulos
for columna, num_nulos in zip(columnas_con_nulos, num_nulos_por_columna):
    indices_nulos = np.random.choice(videogames.index, size=num_nulos, replace=False)
    videogames.loc[indices_nulos, columna] = np.nan

# %%
nulls = videogames.isnull().sum()
rows = videogames.shape[0]

percentage = nulls / rows
table = pd.concat([nulls, percentage], axis=1, keys=['Nulos', 'Porcentaje %'])
ordered_table = table.sort_values(by='Porcentaje %', ascending=False)

print(ordered_table)
# Out:
#               Nulos  Porcentaje %
# Year            271      0.016327
# Name            188      0.011327
# Global_Sales    113      0.006808
# Other_Sales      68      0.004097
# Publisher        58      0.003494
# Platform          0      0.000000
# Genre             0      0.000000
# NA_Sales          0      0.000000
# EU_Sales          0      0.000000
# JP_Sales          0      0.000000

# %% [markdown]
# ## Introduciendo filas duplicadas

# %%
# Número aleatorio de filas a duplicar
num_filas_a_duplicar = random.randint(1, 150)

# Seleccionar filas aleatorias
filas_a_duplicar = videogames.sample(n=num_filas_a_duplicar, replace=True)

# Duplicar las filas seleccionadas
videogames = pd.concat([videogames, filas_a_duplicar])

# Restablecer los índices
videogames.reset_index(drop=True, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Número aleatorio de filas a duplicar
# ----> 2 num_filas_a_duplicar = random.randint(1, 150)
#       4 # Seleccionar filas aleatorias
#       5 filas_a_duplicar = videogames.sample(n=num_filas_a_duplicar, replace=True)
#
# NameError: name 'random' is not defined

# %%
videogames[videogames.duplicated()]
print(f'Total de filas duplicadas: {videogames.duplicated().sum()}')
# Out:
# Total de filas duplicadas: 64

# %%
videogames
# Out:
#                                                     Name Platform    Year  \
# 12040  Crayon Shin-Chan: Densetsu o Yobu Omake no To ...      GBA  2006.0
# 9557                       Cabela's Dangerous Hunts 2009      PS3  2008.0
# 4144                                    Emergency Heroes      Wii  2008.0
# 1279                               WWF WrestleMania 2000      N64  1999.0
# 266                                               Daxter      PSP  2006.0
# ...                                                  ...      ...     ...
# 5799       Ganbare Goemon 2: Kiteretsu Shougun Magginesu     SNES  1993.0
# 1916             Marvel vs. Capcom 3: Fate of Two Worlds     X360  2011.0
# 14665                               Onechanbara Z Kagura     X360  2012.0
# 8814                               Zoids: Battle Legends       GC  2003.0
# 10147           Disney's Peter Pan: Return to Never Land      GBA  2002.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Desordenando el dataframe

# %%
videogames = videogames.sample(frac=1)
videogames
# Out:
#                                                     Name Platform    Year  \
# 12040  Crayon Shin-Chan: Densetsu o Yobu Omake no To ...      GBA  2006.0
# 9557                       Cabela's Dangerous Hunts 2009      PS3  2008.0
# 4144                                    Emergency Heroes      Wii  2008.0
# 1279                               WWF WrestleMania 2000      N64  1999.0
# 266                                               Daxter      PSP  2006.0
# ...                                                  ...      ...     ...
# 5799       Ganbare Goemon 2: Kiteretsu Shougun Magginesu     SNES  1993.0
# 1916             Marvel vs. Capcom 3: Fate of Two Worlds     X360  2011.0
# 14665                               Onechanbara Z Kagura     X360  2012.0
# 8814                               Zoids: Battle Legends       GC  2003.0
# 10147           Disney's Peter Pan: Return to Never Land      GBA  2002.0
#
#           Genre                     Publisher  NA_Sales  EU_Sales  JP_Sales  \
# ...

# %% [markdown]
# ## Exportando dataframe

# %%
videogames.to_csv("./datasets/vgsales_dirty.csv")
